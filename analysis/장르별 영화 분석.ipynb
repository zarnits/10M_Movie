# %% [markdown]
# # 장르별 분석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:\Windows\Fonts\\malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

# %%
movie = pd.read_csv("movie_info_final.csv")

# %%
movie = movie.head(58)      # 58위까지 가져온 데이터 프레임

# %%
movie_1000 = movie.head(29) # 천만영화 데이터 프레임(1~29)

# %%
movie_miss = movie[29:]     # 비천만영화 데이터 프레임(30~58)

# %% [markdown]
# ### 1) 장르별 영화 분포 확인

# %%
## 장르 리스트로 추출 ##
genre = list(movie["Genre"])
genre_1000 = list(movie_1000["Genre"])
genre_miss = list(movie_miss["Genre"])

# %%
genre_list = []
genre_1000_list = []
genre_miss_list = []

for i in genre:
    genre_list.extend(i.split(","))
for i in genre_1000:
    genre_1000_list.extend(i.split(","))
for i in genre_miss:
    genre_miss_list.extend(i.split(","))

# %%
## 장르멸 영화수 데이터 프레임 생성 ##
gdf = pd.DataFrame(pd.value_counts(genre_list))
gdf_1000 = pd.DataFrame(pd.value_counts(genre_1000_list))
gdf_miss = pd.DataFrame(pd.value_counts(genre_miss_list))

# %%
gdf.columns = ["count"]
gdf_1000.columns = ["count"]
gdf_miss.columns = ["count"]

# %%
fig = plt.figure(figsize=(16,6)) # 그래프 위치 지정

ax1 = fig.add_subplot(131)       # 위치 지정
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

#define Seaborn color palette to use
colors = sns.color_palette('pastel')

#create pie chart
ax1.pie(gdf["count"], 
        labels=['액션', '드라마', '어드벤처', 'SF', '코미디', '판타지', '사극', '범죄', '가족', 
                '스릴러', '애니메이션', '전쟁', '뮤지컬'], colors = colors, autopct='%.0f%%')
ax2.pie(gdf_1000["count"], 
        labels=['드라마', '액션', 'SF', '어드벤처', '판타지', '코미디', '가족', 
                '사극', '애니메이션', '범죄', '전쟁', '스릴러', '뮤지컬'], colors = colors, autopct='%.0f%%')
ax3.pie(gdf_miss["count"], 
        labels=['액션', '드라마', '어드벤처', 'SF', '코미디', '사극', '범죄', '스릴러', '판타지'], colors = colors, autopct='%.0f%%')

ax1.set_title("천만 & 비천만 영화(1~58위)")
ax2.set_title("천만 영화(1~28위)")
ax3.set_title("비천만 영화(29~58위)")
# Out:
# Text(0.5, 1.0, '비천만 영화(29~58위)')

# %% [markdown]
#     천만영화는 장르별로 다양하게 분포하고 있는데 그중 드라마, 액션, SF, 어드벤쳐, 판타지에 주로 분포하고 있다.
#     비천만영화는 주로 액션, 드라마, 어드벤쳐, SF, 코미디 정도까지 주된 분포를 이루고 있다.

# %% [markdown]
# ### 2) 장르별 누적 관객수 확인

# %%
g_1000 = movie_1000[["Title", "Genre", "Audi"]]
g_1000.set_index("Title", inplace=True)

# %%
g_1000
# Out:
#                                       Genre      Audi
# Title
# 명량                                    사극,액션  17615919
# 극한직업                                    코미디  16266338
# 신과함께-죄와 벌                           판타지,드라마  14414658
# 국제시장                                    드라마  14264478
# 어벤져스- 엔드게임                            액션,SF  13977602
# 겨울왕국 2                                애니메이션  13750668
# 베테랑                                  액션,드라마  13414484
# 아바타                              SF,액션,어드벤처  13338863
# 도둑들                                   액션,범죄  12984701
# 7번방의 선물                             코미디,드라마  12812144
# 알라딘                             어드벤처,가족,판타지  12797927
# 암살                                   액션,드라마  12706947
# 범죄도시2                                 범죄,액션  12693415
# 광해, 왕이 된 남자                          사극,드라마  12324062
# 신과함께-인과 연                           판타지,드라마  12278010
# 택시운전사                                   드라마  12189706
# 태극기 휘날리며                             전쟁,드라마  11746135
# 부산행                                  액션,스릴러  11567815
# 변호인                                     드라마  11375399
# 해운대                             액션,드라마,어드벤처  11325117
# 어벤져스- 인피니티 워                 액션,어드벤처,판타지,SF  11233176
# 실미도                                      전쟁  11081000
# 괴물                                SF,가족,드라마  10917400
# 아바타- 물의 길                    액션,어드벤처,SF,스릴러  10802350
# 왕의 남자                                   드라마  10514177
# 어벤져스- 에이지 오브 울트론             액션,어드벤처,판타지,SF  10504487
# 인터스텔라                                    SF  10342523
# 기생충                                     드라마  10313519
# 겨울왕국              애니메이션,어드벤처,가족,코미디,뮤지컬,판타지  10305051

# %%
g_miss = movie_miss[["Title", "Genre", "Audi"]]
g_miss.set_index("Title", inplace=True)

# %%
g_miss
# Out:
#                          Genre     Audi
# Title
# 보헤미안 랩소디                   드라마  9948386
# 검사외전                    범죄,코미디  9707581
# 엑시트                     코미디,액션  9426960
# 설국열차                     SF,액션  9353799
# 관상                      사극,드라마  9135806
# 아이언맨 3              액션,어드벤처,SF  9001679
# 캡틴 아메리카- 시빌 워        액션,SF,스릴러  8678761
# 해적- 바다로 간 산적              어드벤처  8666208
# 수상한 그녀                     드라마  8660801
# 백두산                   어드벤처,드라마  8253427
# 과속스캔들                      코미디  8223342
# 탑건- 매버릭                     액션  8195742
# 국가대표                드라마,액션,코미디  8035181
# 스파이더맨- 파 프롬 홈   액션,어드벤처,코미디,SF  8023606
# 디워                      액션,판타지  7855474
# 공조                          액션  7817686
# 트랜스포머 3                액션,어드벤처  7785189
# 히말라야                       드라마  7759761
# 스파이더맨- 노 웨이 홈       액션,어드벤처,SF  7551990
# 미션임파서블-고스트프로토콜              액션  7508976
# 밀정                          액션  7500457
# 최종병기 활                   사극,액션  7470633
# 트랜스포머               SF,액션,어드벤처  7402732
# 트랜스포머- 패자의 역습       SF,액션,어드벤처  7393443
# 써니                     드라마,코미디  7363142
# 한산- 용의 출현               액션,드라마  7264934
# 스파이더맨- 홈 커밍         액션,어드벤처,SF  7258678
# 1987                       드라마  7232452
# 베를린                         액션  7166688

# %%
## 천만 비천만 영화 누적 관객수 담을 데이터 프레임 생성 ##
genre_audi = pd.DataFrame(index=pd.unique(genre_list), columns=["천만영화", "영화수1", "비천만영화", "영화수2"], data=0)

# %%
genre_audi
# Out:
#        천만영화  영화수1  비천만영화  영화수2
# 사극        0     0      0     0
# 액션        0     0      0     0
# 코미디       0     0      0     0
# 판타지       0     0      0     0
# 드라마       0     0      0     0
# SF        0     0      0     0
# 애니메이션     0     0      0     0
# 어드벤처      0     0      0     0
# 범죄        0     0      0     0
# 가족        0     0      0     0
# 전쟁        0     0      0     0
# 스릴러       0     0      0     0
# 뮤지컬       0     0      0     0

# %%
## 장르별로 천만영화 관객수 채워넣기 ##
for gs in g_1000["Genre"]:
    for gss in gs.split(","):
        for idx in range(len(genre_audi)):
            if gss == genre_audi.index[idx]:
                genre_audi["천만영화"][idx] += g_1000["Audi"][idx]
                genre_audi["영화수1"][idx] += 1

# %%
## 장르별로 비천만영화 관객수 채워넣기 ##
for gs in g_miss["Genre"]:
    for gss in gs.split(","):
        for idx in range(len(genre_audi)):
            if gss == genre_audi.index[idx]:
                genre_audi["비천만영화"][idx] += g_miss["Audi"][idx]
                genre_audi["영화수2"][idx] += 1

# %%
## 평균 누적 관람객 수 컬럼 추가 ##
genre_audi["천만영화관객"] = genre_audi["천만영화"] / genre_audi["영화수1"]
genre_audi["비천만영화관객"] = genre_audi["비천만영화"] / genre_audi["영화수2"]

# %%
genre_audi.fillna(0, inplace=True)

# %%
genre_audi
# Out:
#             천만영화  영화수1      비천만영화  영화수2      천만영화관객    비천만영화관객
# 사극      35231838     2   19896772     2  17615919.0  9948386.0
# 액션     195196056    12  184444039    19  16266338.0  9707581.0
# 코미디     43243974     3   56561760     6  14414658.0  9426960.0
# 판타지     85586868     6    9353799     1  14264478.0  9353799.0
# 드라마    195686428    14   82222254     9  13977602.0  9135806.0
# SF      96254676     7   72013432     8  13750668.0  9001679.0
# 애니메이션   26828968     2          0     0  13414484.0        0.0
# 어드벤처    93372041     7   77995872     9  13338863.0  8666208.0
# 범죄      25969402     2    8660801     1  12984701.0  8660801.0
# 가족      38436432     3          0     0  12812144.0        0.0
# 전쟁      25595854     2          0     0  12797927.0        0.0
# 스릴러     25413894     2    8195742     1  12706947.0  8195742.0
# 뮤지컬     12693415     1          0     0  12693415.0        0.0

# %%
genre_audi.to_csv("genre_audi.csv", encoding="utf-8")

# %%
fig = plt.figure(figsize=(20,8)) # 그래프 위치 지정

ax1 = fig.add_subplot(121)       # 위치 지정
ax2 = fig.add_subplot(122)

ax1.set_xlim(0, 2e7)             # 축 사이즈 지정
ax2.set_xlim(0, 2e7)

sns.barplot(x="천만영화관객", y=genre_audi.index, data=genre_audi, ax=ax1, palette="pastel")
sns.barplot(x="비천만영화관객", y=genre_audi.index, data=genre_audi, ax=ax2, palette="pastel")

ax1.set_title("천만영화")
ax2.set_title("비천만영화")
ax1.set_xlabel("장르별 누적 관객수")
ax2.set_xlabel("장르별 누적 관객수")
# Out:
# Text(0.5, 0, '장르별 누적 관객수')

# %% [markdown]
#     공통적으로 사극영화에 누적 관람객 수가 돋보적으로 많다.
#     -> 관객수로만 분석한다면 천만영화를 노리기 위해선 사극장르를 택하는게 좋아보인다.
#        반면 장르 분포를 보면 액션이 월등히 많은데 관객수로 보면 사극이 더 많다.
#
#     -> 주류 장르는 액션인데 관객수는 사극이 더 많은 기묘한 현상(영화수에 비해 관객수가 넘 많음).
#         - 명량이나 관상같이 천만에 든 영화들의 다양한 요인들을 분석한 결과를 도입해서 이런 요인들이 있었기에
#           액션을 뛰어넘어 사극이 이런 많은 관람객수를 달성할 수 있었다? 이런 식으로 끌어가야 할 것 같다.

# %% [markdown]
#     참고 : 장르가 여러 개인 영화는 각 장르마다 중복 추가, 장르별 누적 관객수는 포함되는 영화수로 합한 관객수 나눴음(평균값임).
